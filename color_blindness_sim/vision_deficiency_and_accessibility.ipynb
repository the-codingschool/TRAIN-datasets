# %% [markdown]
# # **Simulating Color Blindness**
#
# ---
#
# #### **Description**
#
# Color blindness, also known as color vision deficiency (CVD), is a condition where individuals have difficulty perceiving certain colors or distinguishing between them accurately. This condition occurs due to abnormalities in the photoreceptor cells of the retina, which are responsible for detecting different wavelengths of light. As a result, individuals with color blindness may perceive colors differently from those with normal color vision.
#
# Color vision deficienies are more prevalent than many people believe. Someone with mild color vision deficiency may not even be aware of their condition if it does not significantly impact their daily activities. It is estimated that 8% (1 in 12) of men and 0.5% (1 in 200) of women have some form of color blindness.
#
#
# The human eye has three types of photoreceptor cells; one perceives long-wavelength light *(L)*, another responds to medium-wavelength light *(M)*, and the last is sensitive short-wavelength *(S)*.
#
# <img style="float: right; margin-left: 10px; margin-bottom: 10px;" src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/04/Cone-fundamentals-with-srgb-spectrum.svg/500px-Cone-fundamentals-with-srgb-spectrum.svg.png" width=300/>
#
#
# The three forms of color blindness we will explore correspond to either the absence or incorrect functioning of these receptor cells:
#
# - **Protanopia** - *(L)* Described by a difficulty distinguishing between red and green, often perceiving them as shades of gray or brown. Often referred to as the inability to percieve **'<font color="#ff2222">red</font>'** light. Protanopia and deuteranopia are the most common forms of color vision deficiency.
#
# - **Deuteranopia** - *(M)* Similar to protanopia, but with a different specific deficiency in the cones responsible for perceiving red and green. Also described as the inability to percieve **'<font color="#41913d">green</font>'** light. Deuteranopia and protanopia are the most common forms of color vision deficiency.
#
# - **Tritanopia** - *(S)* Characterized by the inability to distinguish between blue and yellow hues. Otherwise known as blindness to **'<font color="#5f90d9">blue</font>'** light. Tritanopia is less common than the other types.
#
# Color blind individuals face various challenges in everyday life due to difficulties in perceiving and distinguishing certain colors. One common example is navigating traffic lights, where accurate color perception is crucial for safe driving and pedestrian safety. Fortunately, the vertical layout of traffic lights, with red positioned at the top, yellow in the middle, and green at the bottom, offers clear positional cues that help color blind individuals differentiate between signals.
#
# | Normal Vision | Protanopia | Deuteranopia | Tritanopia |
# | :-----------: | :--------: | :----------: | :--------: |
# | <font color="#cc3232" size=7>●</font><br /><font color="#e7b416" size=7>●</font><br /><font color="#2dc937" size=7>●</font> | <font color="#776D46" size=7>●</font><br /><font color="#d2ba1e" size=7>●</font><br /><font color="#c3ad33" size=7>●</font> | <font color="#89672a" size=7>●</font><br /><font color="#edb01f" size=7>●</font><br /><font color="#d9a449" size=7>●</font> | <font color="#cb3537" size=7>●</font><br /><font color="#f0a6b2" size=7>●</font><br /><font color="#63bac9" size=7>●</font> |
#
#
# Understanding color blindness and its different types is crucial for designing inclusive and accessible visuals, ensuring that information is effectively communicated to all individuals, regardless of their color vision abilities.
#
#
#
# #### **Contents**
# - [**Part 1:** Predict Colors](#predict)
#
#     - [Loading the Data](#load_data)
#     - [Split, Train, Test](#split_train_test)
#     - [View Results](#view_results)
#
#         - [Helper Functions](#step1)
#         - [Initial Results Comparison](#step2)
#         - [Preparing Results for Styling](#step3)
#         - [Style and Show Results](#step4)
#
#     - [Simulating New Colors](#new_colors)
# - [**Part 2:** Assessing Palette Accessibility](#palettes)
#
#     - [Color Difference (&Delta;E)](#color_diff)
#
#     - [Finding Color Difference](#find_delta_e)
#
#     - [Perform Accessibility Test](#accessibility_test)
#
#     - [View Test Results](#view_results_2)
#         - [Data Visualization Demo](#demo)
#
# - [**Part 3:** Simulating Images](#sim_img)
#
#     - [Get and Reshape Image](#sim_step1)
#
#     - [Use Model to Predict](#sim_step2)
#
#     - [Format the Output](#sim_step3)
#
#     - [Display Simulated Images](#sim_step4)

# %% [markdown]
# ---
# ## **Part 1:** Predict Colors   <a name="predict"></a>
#
# ---
#
# The goal of the first half of this project is to create and train a model to predict what colors would look like to individuals with different types of color blindness or color vision deficiency.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %% [markdown]
# ### **Loading the Data**    <a name="load_data"></a>
#
# The model will be trained to take in the RGB values of the ***True color*** and produce the RGB values for what it would look like to someone with ***Protanopia***, ***Deuteranopia***, or ***Tritanopia***.
#
# So we want to separate the **true data** from the **other RGB data**.

# %%
# df = pd.read_csv("color_blind_RGB.csv")
url = "https://raw.githubusercontent.com/the-codingschool/TRAIN/main/color_blindness_sim/color_blind_RGB.csv"
df = pd.read_csv(url)

true_data = df[['true_red','true_green','true_blue']].copy()
other_data = df.drop(columns=['true_red', 'true_green', 'true_blue'])

# %% [markdown]
# ### **Split, Train, Test**  <a name="split_train_test"></a>
#
# Possible sklearn models to use:
# * LinearRegression
# * DecisionTreeRegressor
# * RandomForestRegressor
#
#
# Feel free to break up `other_data` and train your model on one type of color vision deficiency at a time, make note of whether this affects the performance.

# %%
X_train, X_test, y_train, y_test = train_test_split(true_data, other_data, test_size=0.2, random_state=42)

reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
pred = reg_model.predict(X_test)

print("R2: " + str(metrics.r2_score(y_test, pred)))
print("MSE: " + str(metrics.mean_squared_error(y_test, pred)))
print("MAE: " + str(metrics.mean_absolute_error(y_test, pred)))
# Out:
# R2: 0.952213879916472
# MSE: 236.63232163653115
# MAE: 10.624655616329685

# %% [markdown]
# ### **View Results**    <a name="view_results"></a>

# %% [markdown]
# ##### **Step 1:** Helper Functions  <a name="step1"></a>
#
# The following functions will help format the output table to be visually digestible:
#
# * `make_hex_col()`: Combines the red, green, and blue columns of a vision type into one hexadecimal code that will be used to color the background of a table cell. Takes a dataframe object and color vision type *(true, prot, deut, trit)* as parameters and returns a list of all the RGB color samples as HEX codes, ready to be added to a dataframe as a new column. This allows the `output_cell_styling` function to show us the exact color of a sample. <br />
# To learn more about the process of converting RGB to HEX, see this [infographic](https://drive.google.com/file/d/17SjN9rsOv57Y7V1nECDT1R4lGu2yLHq7/view?usp=sharing).
#
# * `text_color_from_ratio()`: Takes a hex code as a parameter and uses standards set by [WCAG](https://www.w3.org/TR/WCAG21/#contrast-minimum) to determine whether text on top of this hex color should be **black** or **white** for visibility. This function determines the [contrast ratio](https://www.w3.org/TR/WCAG21/#dfn-contrast-ratio) of the input color to white by computing the [relative luminance](https://www.w3.org/TR/WCAG21/#dfn-relative-luminance) of the input color. The contrast ratio will determine whether black or white will stand out better against the background color and can be easily read. To learn more about the math involved, visit any of the linked webpages.
#
# * `output_cell_styling()`: Takes a feature column as a parameter and returns a list of styling instructions for each column value as strings. These styling instructions are CSS ([cascading style sheets](https://www.w3schools.com/css/css_intro.asp)) ***attribute:value*** pairs. The primary attributes to consider are:
#     - **Background Color** `background-color` - Accepts hex codes (ex: #012D9C) and some standard [color names](https://developer.mozilla.org/en-US/docs/Web/CSS/named-color) (ex: 'red'). At a glance, the background should show us exactly what the sample color looks like *(hex code)* and the colors of the predicted/actual labels *(word name)*.
#     - **Text Color** `color` - Accepts hex codes (ex: #012D9C) and some standard [color names](https://developer.mozilla.org/en-US/docs/Web/CSS/named-color) (ex: 'red'). We want to manipulate the color of the text so that it can be properly seen/read against the background color.
#
#     When the name of this function is used as a parameter in this method call `df.style.apply()` it is called on each feature column in `df`.

# %% [markdown]
# <h5 style="color: #999"> <b>Instructor Note:</b> Consider giving the following code cell to students, possibly have them complete <b>make_hex_col()</b> themselves. </h5>

# %%
"""
Combine the RGB features into one hex code for each sample using string formatting.
The model may have predicted some values outside the 0-255 range.
  - Any negative RGB value is set to 0
  - Any RGB value above 255 is set to 255
Return all hex codes as a list so it can be added as a new column to the dataframe.
"""
def make_hex_col(frame, cv_type):
    hex_vals = []
    for index, row in frame.iterrows():
        r = 0 if int(row[cv_type + '_red']) < 0 else 255 if int(row[cv_type + '_red']) > 255 else int(row[cv_type + '_red']) 
        g = 0 if int(row[cv_type + '_green']) < 0 else 255 if int(row[cv_type + '_green']) > 255 else int(row[cv_type + '_green']) 
        b = 0 if int(row[cv_type + '_blue']) < 0 else 255 if int(row[cv_type + '_blue']) > 255 else int(row[cv_type + '_blue']) 
        hex_vals.append(('#%02X%02X%02X' % (r, g, b)))
    return hex_vals

"""
Revert hex color parameter to RGB for contrast ratio analysis.
Dark colors need white text and light colors need black text for appropriate visibility.
Learn more about this process by visiting the resources linked above.
"""
def text_color_from_ratio(hex):
    rgb = matplotlib.colors.to_rgb(hex)
    lum  = (rgb[0] / 12.92 if rgb[0] <= 0.03928 else ( (rgb[0] + 0.055) / 1.055) ** 2.4) * 0.2126
    lum += (rgb[1] / 12.92 if rgb[1] <= 0.03928 else ( (rgb[1] + 0.055) / 1.055) ** 2.4) * 0.7152
    lum += (rgb[2] / 12.92 if rgb[2] <= 0.03928 else ( (rgb[2] + 0.055) / 1.055) ** 2.4) * 0.0722
    ratio = lum if lum > 1 else 5 if lum == 0 else 1/lum
    return 'white' if ratio >= 4.5 else 'black'

"""
For styling hex columns: center-align text, set bg color to hex, and color text for visibility.
"""
def output_cell_styling(column):
    return ['text-align: center; color: ' + text_color_from_ratio(val) + '; background-color: ' + val.lower() for val in column]

# %% [markdown]
# ##### **Step 2:** Initial Results Comparison    <a name="step2"></a>
#
# Compile the actual and predicted colors for all vision types into a single dataframe for easy side-by-side comparison. The three RGB columns for all of the true/actual/predicted colors should be simplified into one column of hex codes. In total, there should be 7 columns: 1 for true colors and 2 (actual & predicted) for each of the three color vision deficiency types.
#
# However, before calling `make_hex_col()` on any of the predicted data, `pred` must be formatted as a dataframe with the same column names as `y_test`.
#
# From here, you could opt to skip steps 3 & 4 and simply run this line of code to see the results without more advanced styling:
#
# ```python
#     results_df.style.apply(output_cell_styling)
# ```

# %%
pred_df = pd.DataFrame(pred, columns=y_test.columns)

results_df = pd.DataFrame()
results_df['true'] = make_hex_col(X_test, 'true')
results_df['prot actual'] = make_hex_col(y_test, 'prot')
results_df['prot pred'] = make_hex_col(pred_df, 'prot')
results_df['deut actual'] = make_hex_col(y_test, 'deut')
results_df['deut pred'] = make_hex_col(pred_df, 'deut')
results_df['trit actual'] = make_hex_col(y_test, 'trit')
results_df['trit pred'] = make_hex_col(pred_df, 'trit')

results_df
# Out:
#          true prot actual prot pred deut actual deut pred trit actual  \
# 0     #A3F548     #FADE44   #FFD850     #FFD8A5   #FFCE76     #BDE4F6
# 1     #10C704     #C1AA00   #C49600     #D8A12E   #CA8D2E     #5CB7C6
# 2     #43BDED     #A0ADE3   #8FABD9     #98ADF2   #8EABE5     #2BC1D0
# 3     #AA91A9     #9496AB   #92A1AD     #9F93A6   #A09FA7     #A7929D
# 4     #09435C     #394058   #30474F     #33405E   #33474E     #00474D
# ...       ...         ...       ...         ...       ...         ...
# 1006  #BE83DC     #7996EA   #7DA0DF     #8497D4   #8CA0CC     #B1909B
# 1007  #52703D     #72673D   #76713D     #7D6343   #816D45     #5C6972
# 1008  #873969     #4A5579   #455D70     #585462   #555C5A     #824348
# 1009  #A73DE2     #006EE5   #346FE3     #0074CA   #4072BC     #8F6870
# 1010  #76F679     #F2DB70   #EFD375     #FFD3A1   #F9CB9C     #97E7F9
#
#      trit pred
# 0      #C7D8E9
# 1      #3FA8B6
# 2      #43C5D4
# 3      #A699A4
# 4      #0C4F55
# ...        ...
# 1006   #AD96A1
# 1007   #606E76
# 1008   #7D4A4F
# 1009   #876067
# 1010   #94E0F2
#
# [1011 rows x 7 columns]

# %% [markdown]
# ##### **Step 3:** Prepare Results for Styling   <a name="step3"></a>
#
# In the end, we want our output table to have two header rows:
# * the top row will separate the columns into the 4 color vision types
# * the second row will denote the "Actual" and "Predicted" columns for each type
#
# To do this, we need to add an additional column to the results dataframe to serve as the "Predicted" column for the True color type. This will allow the second line of the following code to properly reformat the columns. Don't worry! This extra column will essentially be removed in Step 4.

# %%
results_df.insert(1, 'extra', len(pred)*['#000000'], True)
results_df.columns = columns=pd.MultiIndex.from_product([['True', 'Protanopia', 'Deuteranopia', 'Tritanopia'],['Actual', 'Predicted']])

# %% [markdown]
# ##### **Step 4:** Style and Show Results    <a name="step4"></a>
#
# In order, the following code block applies these styling steps to the output table:
#
# * Apply background and text coloring to all table cells.
# * Hide the extra "True, Predicted" column added in Step 3.
# * Center all of the table's heading and subheading text.
# * Add small column separation between the 4 vision types. *(this may not appear in all editors)*
#
#
# When run in an appropriate notebook environment (Google Colab, VSCode, etc), the resulting output table should be easy to read/understand (and even more visually appealing!). See the [pandas documentation](https://pandas.pydata.org/docs/user_guide/style.html) to learn more about table visualization and styling.

# %%
results_df.style.apply(output_cell_styling) \
    .hide([('True', 'Predicted')], axis="columns") \
    .set_table_styles([{'selector': 'th', 'props': 'text-align: center;'}], overwrite=False) \
    .set_table_styles({(x, 'Actual'): [{'selector': 'td, th', 'props': 'border-left: 4px solid #d5d5d5;'}] for x in ['Protanopia', 'Deuteranopia', 'Tritanopia']}, overwrite=False)
# Out:
# <style type="text/css">
# #T_9d6c0 th {
#   text-align: center;
# }
# #T_9d6c0 td.col2 {
#   border-left: 4px solid #d5d5d5;
# }
# #T_9d6c0  th.col2 {
#   border-left: 4px solid #d5d5d5;
# }
# #T_9d6c0 td.col4 {
#   border-left: 4px solid #d5d5d5;
# }
# #T_9d6c0  th.col4 {
#   border-left: 4px solid #d5d5d5;
# }
# #T_9d6c0 td.col6 {
#   border-left: 4px solid #d5d5d5;
# }
# #T_9d6c0  th.col6 {
#   border-left: 4px solid #d5d5d5;
# }
# #T_9d6c0_row0_col0 {
#   text-align: center;
#   color: black;
#   background-color: #a3f548;
# }
# #T_9d6c0_row0_col2 {
#   text-align: center;
#   color: black;
#   background-color: #fade44;
# }
# #T_9d6c0_row0_col3 {
#   text-align: center;
#   color: black;
#   background-color: #ffd850;
# }
# #T_9d6c0_row0_col4 {
#   text-align: center;
#   color: black;
#   background-color: #ffd8a5;
# }
# #T_9d6c0_row0_col5 {
#   text-align: center;
#   color: black;
#   background-color: #ffce76;
# }
# #T_9d6c0_row0_col6 {
#   text-align: center;
#   color: black;
#   background-color: #bde4f6;
# }
# #T_9d6c0_row0_col7 {
#   text-align: center;
#   color: black;
#   background-color: #c7d8e9;
# }
# #T_9d6c0_row1_col0 {
#   text-align: center;
#   color: black;
#   background-color: #10c704;
# }
# #T_9d6c0_row1_col2 {
#   text-align: center;
#   color: black;
#   background-color: #c1aa00;
# }
# #T_9d6c0_row1_col3 {
#   text-align: center;
#   color: black;
#   background-color: #c49600;
# }
# #T_9d6c0_row1_col4 {
#   text-align: center;
#   color: black;
#   background-color: #d8a12e;
# }
# #T_9d6c0_row1_col5 {
#   text-align: center;
#   color: black;
#   background-color: #ca8d2e;
# }
# #T_9d6c0_row1_col6 {
#   text-align: center;
#   color: black;
#   background-color: #5cb7c6;
# }
# #T_9d6c0_row1_col7 {
#   text-align: center;
#   color: black;
#   background-color: #3fa8b6;
# }
# #T_9d6c0_row2_col0 {
#   text-align: center;
#   color: black;
#   background-color: #43bded;
# }
# #T_9d6c0_row2_col2 {
#   text-align: center;
#   color: black;
#   background-color: #a0ade3;
# }
# #T_9d6c0_row2_col3 {
#   text-align: center;
#   color: black;
#   background-color: #8fabd9;
# }
# #T_9d6c0_row2_col4 {
#   text-align: center;
#   color: black;
#   background-color: #98adf2;
# }
# #T_9d6c0_row2_col5 {
#   text-align: center;
#   color: black;
#   background-color: #8eabe5;
# }
# #T_9d6c0_row2_col6 {
#   text-align: center;
#   color: black;
#   background-color: #2bc1d0;
# }
# #T_9d6c0_row2_col7 {
#   text-align: center;
#   color: black;
#   background-color: #43c5d4;
# }
# #T_9d6c0_row3_col0 {
#   text-align: center;
#   color: black;
#   background-color: #aa91a9;
# }
# #T_9d6c0_row3_col2 {
#   text-align: center;
#   color: black;
#   background-color: #9496ab;
# }
# #T_9d6c0_row3_col3 {
#   text-align: center;
#   color: black;
#   background-color: #92a1ad;
# }
# #T_9d6c0_row3_col4 {
#   text-align: center;
#   color: black;
#   background-color: #9f93a6;
# }
# #T_9d6c0_row3_col5 {
#   text-align: center;
#   color: black;
#   background-color: #a09fa7;
# }
# #T_9d6c0_row3_col6 {
#   text-align: center;
#   color: black;
#   background-color: #a7929d;
# }
# #T_9d6c0_row3_col7 {
#   text-align: center;
#   color: black;
#   background-color: #a699a4;
# }
# #T_9d6c0_row4_col0 {
#   text-align: center;
#   color: white;
#   background-color: #09435c;
# }
# #T_9d6c0_row4_col2 {
#   text-align: center;
#   color: white;
#   background-color: #394058;
# }
# #T_9d6c0_row4_col3 {
#   text-align: center;
#   color: white;
#   background-color: #30474f;
# }
# #T_9d6c0_row4_col4 {
#   text-align: center;
#   color: white;
#   background-color: #33405e;
# }
# #T_9d6c0_row4_col5 {
#   text-align: center;
#   color: white;
#   background-color: #33474e;
# }
# #T_9d6c0_row4_col6 {
#   text-align: center;
#   color: white;
#   background-color: #00474d;
# }
# #T_9d6c0_row4_col7 {
#   text-align: center;
#   color: white;
#   background-color: #0c4f55;
# }
# #T_9d6c0_row5_col0 {
#   text-align: center;
#   color: black;
#   background-color: #52a980;
# }
# #T_9d6c0_row5_col2 {
#   text-align: center;
#   color: black;
#   background-color: #a19778;
# }
# #T_9d6c0_row5_col3 {
#   text-align: center;
#   color: black;
#   background-color: #9b9a78;
# }
# #T_9d6c0_row5_col4 {
#   text-align: center;
#   color: black;
#   background-color: #ad9286;
# }
# #T_9d6c0_row5_col5 {
#   text-align: center;
#   color: black;
#   background-color: #a2968a;
# }
# #T_9d6c0_row5_col6 {
#   text-align: center;
#   color: black;
#   background-color: #62a1ae;
# }
# #T_9d6c0_row5_col7 {
#   text-align: center;
#   color: black;
#   background-color: #60a5b1;
# }
# #T_9d6c0_row6_col0 {
#   text-align: center;
#   color: black;
#   background-color: #b1aa2e;
# }
# #T_9d6c0_row6_col2 {
#   text-align: center;
#   color: black;
#   background-color: #baa531;
# }
# #T_9d6c0_row6_col3 {
#   text-align: center;
#   color: black;
#   background-color: #c9aa3d;
# }
# #T_9d6c0_row6_col4 {
#   text-align: center;
#   color: black;
#   background-color: #d09c37;
# }
# #T_9d6c0_row6_col5 {
#   text-align: center;
#   color: black;
#   background-color: #dfa24d;
# }
# #T_9d6c0_row6_col6 {
#   text-align: center;
#   color: black;
#   background-color: #bb9da9;
# }
# #T_9d6c0_row6_col7 {
#   text-align: center;
#   color: black;
#   background-color: #c89aa5;
# }
# #T_9d6c0_row7_col0 {
#   text-align: center;
#   color: black;
#   background-color: #d282e5;
# }
# #T_9d6c0_row7_col2 {
#   text-align: center;
#   color: black;
#   background-color: #7b9cf9;
# }
# #T_9d6c0_row7_col3 {
#   text-align: center;
#   color: black;
#   background-color: #7fa5eb;
# }
# #T_9d6c0_row7_col4 {
#   text-align: center;
#   color: black;
#   background-color: #8a9ddb;
# }
# #T_9d6c0_row7_col5 {
#   text-align: center;
#   color: black;
#   background-color: #8fa5d3;
# }
# #T_9d6c0_row7_col6 {
#   text-align: center;
#   color: black;
#   background-color: #c5919d;
# }
# #T_9d6c0_row7_col7 {
#   text-align: center;
#   color: black;
#   background-color: #be97a2;
# }
# #T_9d6c0_row8_col0 {
#   text-align: center;
#   color: black;
#   background-color: #35d667;
# }
# #T_9d6c0_row8_col2 {
#   text-align: center;
#   color: black;
#   background-color: #ceba5e;
# }
# #T_9d6c0_row8_col3 {
#   text-align: center;
#   color: black;
#   background-color: #c4af5b;
# }
# #T_9d6c0_row8_col4 {
#   text-align: center;
#   color: black;
#   background-color: #e3b173;
# }
# #T_9d6c0_row8_col5 {
#   text-align: center;
#   color: black;
#   background-color: #c8a882;
# }
# #T_9d6c0_row8_col6 {
#   text-align: center;
#   color: black;
#   background-color: #66c8d8;
# }
# #T_9d6c0_row8_col7 {
#   text-align: center;
#   color: black;
#   background-color: #53c4d3;
# }
# #T_9d6c0_row9_col0 {
#   text-align: center;
#   color: white;
#   background-color: #d32248;
# }
# #T_9d6c0_row9_col2 {
#   text-align: center;
#   color: white;
#   background-color: #726d62;
# }
# #T_9d6c0_row9_col3 {
#   text-align: center;
#   color: white;
#   background-color: #4b5d5f;
# }
# #T_9d6c0_row9_col4 {
#   text-align: center;
#   color: white;
#   background-color: #86683e;
# }
# #T_9d6c0_row9_col5 {
#   text-align: center;
#   color: white;
#   background-color: #665b3c;
# }
# #T_9d6c0_row9_col6 {
#   text-align: center;
#   color: white;
#   background-color: #d12d2e;
# }
# #T_9d6c0_row9_col7 {
#   text-align: center;
#   color: white;
#   background-color: #c63437;
# }
# #T_9d6c0_row10_col0 {
#   text-align: center;
#   color: white;
#   background-color: #a35ba8;
# }
# #T_9d6c0_row10_col2 {
#   text-align: center;
#   color: white;
#   background-color: #5a73b8;
# }
# #T_9d6c0_row10_col3 {
#   text-align: center;
#   color: white;
#   background-color: #5d7dad;
# }
# #T_9d6c0_row10_col4 {
#   text-align: center;
#   color: white;
#   background-color: #68749f;
# }
# #T_9d6c0_row10_col5 {
#   text-align: center;
#   color: white;
#   background-color: #6c7d96;
# }
# #T_9d6c0_row10_col6 {
#   text-align: center;
#   color: white;
#   background-color: #996870;
# }
# #T_9d6c0_row10_col7 {
#   text-align: center;
#   color: white;
#   background-color: #946f76;
# }
# #T_9d6c0_row11_col0 {
#   text-align: center;
#   color: black;
#   background-color: #2abe6d;
# }
# #T_9d6c0_row11_col2 {
#   text-align: center;
#   color: black;
#   background-color: #b5a564;
# }
# #T_9d6c0_row11_col3 {
#   text-align: center;
#   color: black;
#   background-color: #a99d60;
# }
# #T_9d6c0_row11_col4 {
#   text-align: center;
#   color: black;
#   background-color: #c59e77;
# }
# #T_9d6c0_row11_col5 {
#   text-align: center;
#   color: black;
#   background-color: #ac987f;
# }
# #T_9d6c0_row11_col6 {
#   text-align: center;
#   color: black;
#   background-color: #56b2c1;
# }
# #T_9d6c0_row11_col7 {
#   text-align: center;
#   color: black;
#   background-color: #43b2c0;
# }
# #T_9d6c0_row12_col0 {
#   text-al

# %% [markdown]
# ### **Simulating New Colors**   <a name="new_colors"></a>
#
# Now that you have a trained model, try testing it on your own RGB colors to predict how they might look to individuals with color blindness.
#
# * **Step 1:** Create a list of your colors in RGB format (these are the 'true' colors). Then, format the list into a DataFrame with proper column names.
#
# * **Step 2:** Perform a prediction on your test data using your regression model. Reformat the prediction data into a DataFrame with proper column names (Remember, this is necessary to create hex columns for the output table).
#
# * **Step 3:** Create a new DataFrame and add hex color columns of all 4 vision types. Again, this will allow you to view all of the predicted colors side-by-side.
#
# * **Step 4:** Apply cell styling to the DataFrame table.

# %%
# Step 1
my_colors = [[109, 199, 44], [163, 91, 168], [211, 34, 72], [220, 54, 126]]
my_X_test = pd.DataFrame(my_colors, columns=X_test.columns)

# Step 2
my_pred = reg_model.predict(my_X_test)
my_pred = pd.DataFrame(my_pred, columns=y_test.columns)

# Step 3
my_results_df = pd.DataFrame()
my_results_df['True'] = make_hex_col(my_X_test, 'true')
my_results_df['Protanopia'] = make_hex_col(my_pred, 'prot')
my_results_df['Deuteranopia'] = make_hex_col(my_pred, 'deut')
my_results_df['Tritanopia'] = make_hex_col(my_pred, 'trit')

# Step 4
my_results_df.style.apply(output_cell_styling)
# Out:
# <style type="text/css">
# #T_a63c8_row0_col0 {
#   text-align: center;
#   color: black;
#   background-color: #6dc72c;
# }
# #T_a63c8_row0_col1 {
#   text-align: center;
#   color: black;
#   background-color: #d3ad2f;
# }
# #T_a63c8_row0_col2 {
#   text-align: center;
#   color: black;
#   background-color: #e1a451;
# }
# #T_a63c8_row0_col3 {
#   text-align: center;
#   color: black;
#   background-color: #8fafbd;
# }
# #T_a63c8_row1_col0 {
#   text-align: center;
#   color: white;
#   background-color: #a35ba8;
# }
# #T_a63c8_row1_col1 {
#   text-align: center;
#   color: white;
#   background-color: #5d7dad;
# }
# #T_a63c8_row1_col2 {
#   text-align: center;
#   color: white;
#   background-color: #6c7d96;
# }
# #T_a63c8_row1_col3 {
#   text-align: center;
#   color: white;
#   background-color: #946f76;
# }
# #T_a63c8_row2_col0 {
#   text-align: center;
#   color: white;
#   background-color: #d32248;
# }
# #T_a63c8_row2_col1 {
#   text-align: center;
#   color: white;
#   background-color: #4b5d5f;
# }
# #T_a63c8_row2_col2 {
#   text-align: center;
#   color: white;
#   background-color: #665b3c;
# }
# #T_a63c8_row2_col3 {
#   text-align: center;
#   color: white;
#   background-color: #c63437;
# }
# #T_a63c8_row3_col0 {
#   text-align: center;
#   color: white;
#   background-color: #dc367e;
# }
# #T_a63c8_row3_col1 {
#   text-align: center;
#   color: white;
#   background-color: #537091;
# }
# #T_a63c8_row3_col2 {
#   text-align: center;
#   color: white;
#   background-color: #6c6e6d;
# }
# #T_a63c8_row3_col3 {
#   text-align: center;
#   color: white;
#   background-color: #c94c51;
# }
# </style>
# <table id="T_a63c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a63c8_level0_col0" class="col_heading level0 col0" >True</th>
#       <th id="T_a63c8_level0_col1" class="col_heading level0 col1" >Protanopia</th>
#       <th id="T_a63c8_level0_col2" class="col_heading level0 col2" >Deuteranopia</th>
#       <th id="T_a63c8_level0_col3" class="col_heading level0 col3" >Tritanopia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a63c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a63c8_row0_col0" class="data row0 col0" >#6DC72C</td>
#       <td id="T_a63c8_row0_col1" class="data row0 col1" >#D3AD2F</td>
#       <td id="T_a63c8_row0_col2" class="data row0 col2" >#E1A451</td>
#       <td id="T_a63c8_row0_col3" class="data row0 col3" >#8FAFBD</td>
#     </tr>
#     <tr>
#       <th id="T_a63c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a63c8_row1_col0" class="data row1 col0" >#A35BA8</td>
#       <td id="T_a63c8_row1_col1" class="data row1 col1" >#5D7DAD</td>
#       <td id="T_a63c8_row1_col2" class="data row1 col2" >#6C7D96</td>
#       <td id="T_a63c8_row1_col3" class="data row1 col3" >#946F76</td>
#     </tr>
#     <tr>
#       <th id="T_a63c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a63c8_row2_col0" class="data row2 col0" >#D32248</td>
#       <td id="T_a63c8_row2_col1" class="data row2 col1" >#4B5D5F</td>
#       <td id="T_a63c8_row2_col2" class="data row2 col2" >#665B3C</td>
#       <td id="T_a63c8_row2_col3" class="data row2 col3" >#C63437</td>
#     </tr>
#     <tr>
#       <th id="T_a63c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a63c8_row3_col0" class="data row3 col0" >#DC367E</td>
#       <td id="T_a63c8_row3_col1" class="data row3 col1" >#537091</td>
#       <td id="T_a63c8_row3_col2" class="data row3 col2" >#6C6E6D</td>
#       <td id="T_a63c8_row3_col3" class="data row3 col3" >#C94C51</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ## **Part 2:** Assess Color Palette Accessibility  <a name="palettes"></a>
#
# ---
#
# When selecting a single color, like a background color or a text color, it's relatively straightforward to choose one that is easily distinguishable and readable. However, the challenge arises when attempting to pick multiple colors to form a palette, such as for a website design, data visualization, or artwork.
#
# Imagine you're designing a chart with multiple data series, each represented by a different color. If you use a palette that includes shades of red and green to differentiate between the series, someone with red-green color blindness may struggle to distinguish between them. This can lead to confusion and difficulty interpreting the information presented.

# %% [markdown]
# ![Figure_1.png](data:image/png;base64,...)

# %% [markdown]
# See [Confusion Lines](https://www.color-blindness.com/2009/01/19/colorblind-colors-of-confusion/) to learn more about how certain colors become indistinguishable to people with color vision deficiency.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/6b/Color_Blind_Confusion_Lines.png" width="350" />

# %% [markdown]
# ### **Color Difference**    <a name="color_diff"></a>
#
# Oftentimes, designers will simply use [contrast ratio](https://www.w3.org/TR/WCAG21/#dfn-contrast-ratio) to ensure the colors in their palettes can be differentiated by anyone. Selecting high contrast colors will usually allow even those with \*[Achromatopsia](#achromatopsia) to differentiate colors based on how light or dark they appear. However, this method can be rather restrictive since there are colors with low contrast that are still easily distinguishable by those with either protanopia, deuteranopia, or tritanopia.
#
# Another way to ensure palette accessibility with fewer limitations is by using **Color Difference**!
#
# **Color Difference**, otherwise referred to as **color distance** or **Delta E (&Delta;E)**, is a metric used to quantify the difference between two colors. It is a measure of how distinguishable two colors are from each other. Color difference (&Delta;E) values are commonly used in various industries such as printing, textiles, and manufacturing to ensure consistency and accuracy in color reproduction. This means that **&Delta;E can also be used to evaluate the performance of the model created in Part 1** by finding the distance between the predicted and actual values! In this instance, a lower &Delta;E is better and indicates a more accurate prediction.
#
# Delta E is measured on a scale from 0 to 100. The higher the &Delta;E value, the greater the perceived difference between the two colors. In general, a &Delta;E value below 1 is considered imperceptible to the human eye, while values between 1 and 2 are barely perceptible. Values above 2 indicate noticeable differences, and values above 10 are typically considered to represent very noticeable differences.
#
#
# | Color 1 | Color 2 | Color Difference (&Delta;E) |
# | ------- | ------- | --------------------------: |
# | **#FFFFFF** (white) | **#000000** (black) | **~100.000** |
# | **<font color="#DB54F0">#DB54F0</font>** (fuchsia) | **<font color="#DB54F0">#DB54F0</font>** (fuchsia) | **0.000** |
#
#
# As you can see, &Delta;E of black and white is ~100 since the two colors are essentially opposites, while &Delta;E of two instances of the same exact color is 0.
#
# ***But why does knowing this help us?***
#
# As previously mentioned, having a type of red-green color blindness (protanopia or deuteranopia) makes it difficult to distinguish certain shades of red, orange, brown, green, etc. While this **<font color="#6DC72C">green</font>** color may look completely different from this **<font color="#FF8E00">orange</font>** color to those with normal vision, they end up looking nearly identical to those with either protanopia or deuteranopia. So even though a combination of these two colors is acceptable for some, it is not accessible to everyone.
#
# The table below demonstrates how dramatically &Delta;E changes depending on the vision type.
#
#
# | Vision Type | Color 1 | Color 2 | Color Difference (&Delta;E) | Accessibility |
# | ----------- | ------- | ------- | --------------------------: | :-----------: |
# | True        | **<font color="#6DC72C">#6DC72C</font>** (green) | **<font color="#FF8E00">#FF8E00</font>** (orange) | **47.851** | Great |
# | Protanopia  | **<font color="#C7B02B">#C7B02B</font>** (muddy yellow) | **<font color="#C0AA13">#C0AA13</font>** (muddy yellow) |  **2.035** | Poor  |
# | Deuteranopia| **<font color="#DEA73E">#DEA73E</font>** (yellow-orange) | **<font color="#D8A100">#D8A100</font>** (yellow-orange) |  **4.217** | Poor  |
# | Tritanopia  | **<font color="#88B8C6">#88B8C6</font>** (light blue) | **<font color="#FF868E">#FF868E</font>** (coral pink) | **44.656** | Great |
#
#
# Here is a different example of two colors that most people can differentiate, but are practically indistinguishable to those with blue-yellow color blindness (tritanopia).
#
#
# | Vision Type | Color 1 | Color 2 | Color Difference (&Delta;E) | Accessibility |
# | ----------- | ------- | ------- | --------------------------: | :-----------: |
# | True        | **<font color="#F986A0">#F986A0</font>** (pink) | **<font color="#FF8E00">#FF8E00</font>** (orange) | **35.946** | Good  |
# | Protanopia  | **<font color="#A8A7B0">#A8A7B0</font>** (bluish gray) | **<font color="#C0AA13">#C0AA13</font>** (muddy yellow) | **33.458** | Good  |
# | Deuteranopia| **<font color="#BFA297">#BFA297</font>** (pinkish gray) | **<font color="#D8A100">#D8A100</font>** (yellow-orange) | **24.641** | Okay  |
# | Tritanopia  | **<font color="#F78791">#F78791</font>** (coral pink) | **<font color="#FF868E">#FF868E</font>** (coral pink) |  **1.736** | Poor  |
#
#
# <a name="achromatopsia"></a> *<span style="font-size: small"> *Achromatopsia - Sees no color at all, only black, gray, and white. It is the rarest form of color blindness.</span>*
#
# ---
#
#
# #### **Your Task**
#
# >The goal of Part 2 is to be able to assess whether a palette of colors passes an accessibility test for all 4 vision types. After using your model to predict the *prot.,* *deut.,* and *trit.* equivalents to a given set of *true colors*, find &Delta;E of every pair of colors in each collection. If &Delta;E is above a certain threshold or tolerance level for every possible pair, the palette passes for that vision type. You get to decide the tolerance threshold, the default is 10. The higher the tolerance threshold is, the harder it will be to pass but the more accessible your results will end up being. A palette is only truly accessible if it passes for *true*, *prot.*, *deut.*, and *trit.*
#
# ---

# %% [markdown]
# ### **Finding Color Difference (&Delta;E)**     <a name="find_delta_e"></a>
#
# There are several ways to calculate color difference. Many of these methods have been outlined by the International Commission on Illumination (CIE), whose most recent and arguably most accurate implementation being **CIEDE2000** (also called CIE2000). Determining &Delta;E from the CIEDE2000 definition of color distance is a mathematically intense process that involves more than a dozen formulas. The entire process can be found [here](https://hajim.rochester.edu/ece/sites/gsharma/ciede2000/ciede2000noteCRNA.pdf).
#
# Fortunately, there is a python library that we can use to calculate &Delta;E from the CIEDE2000 method. It is called `colormath` and must first be installed by running the following line of code.

# %% [markdown]
# <h5 style="color: #999"> <b>Instructor Note:</b> These code cells should be given to students. </h5>

# %%
# !pip install colormath

# %%
from colormath.color_objects import LabColor, sRGBColor
from colormath.color_conversions import convert_color
from colormath.color_diff import _get_lab_color1_vector, _get_lab_color2_matrix
from colormath import color_diff_matrix

def delta_e_cie2000(color1, color2, Kl=1, Kc=1, Kh=1):
    """
    Calculates the Delta E (CIE2000) of two colors (as LabColor objects).

    This function already exists in the colormath.color_diff library 
    however, it attempts to use an outdated numpy method that causes an error
    so it has been rewritten here without the faulty code.
    """
    color1_vector = _get_lab_color1_vector(color1)
    color2_matrix = _get_lab_color2_matrix(color2)
    delta_e = color_diff_matrix.delta_e_cie2000(color1_vector, color2_matrix, Kl=Kl, Kc=Kc, Kh=Kh)[0]
    return delta_e


def find_color_diff(hex1, hex2):
    """
    Converts two hex colors to sRGB and then to Lab format before starting CIEDE2000.
    """
    rgb1 = sRGBColor.new_from_rgb_hex(hex1)
    rgb2 = sRGBColor.new_from_rgb_hex(hex2)
    lab1 = convert_color(rgb1, LabColor)
    lab2 = convert_color(rgb2, LabColor)
    return delta_e_cie2000(lab1, lab2)


def is_palette_accessible(color_list=[], tolerance=10):
    """
    Compares each color to the other colors in the list.
    Returns True if delta_e for all pairs is >=tolerance.
    Creates & returns 3 lists to be used as columns when viewing the accessibility test results for each vision type.
    """
    is_accessible = True
    col1 = []
    col2 = []
    diff = []
    for i in range(len(color_list)):
        for j in range(i + 1, len(color_list)):
            delta_e = find_color_diff(color_list[i], color_list[j])
            is_accessible = is_accessible and delta_e >= tolerance
            col1.append(color_list[i])
            col2.append(color_list[j])
            diff.append(delta_e)

    return is_accessible, col1, col2, diff

# %% [markdown]
# ### **Perform Accessibility Test & Record Results**     <a name="accessibility_test"></a>
#
# This code block reuses the same colors and resulting DataFrame object from the end of Part 1, but feel free to make your own palette with any number of colors and create a new DataFrame by following the steps in ***Part 1: Simulating New Colors***.

# %%
# adjust the tolerance_threshold value as desired
# a higher tolerance means the colors need to have greater distance to pass as accessible
tolerance_threshold = 10

accessible_all_types = True
pass_fail = []                  # records whether each test passed or failed
comparison_tables = {}          # saves the test details for each vision type
for vision_type, color_list in my_results_df.items():
    accessible, col1, col2, diff = is_palette_accessible(color_list, tolerance_threshold)
    pass_fail.append('Pass' if accessible else 'Fail')
    accessible_all_types = accessible_all_types and accessible
    comparison_tables[vision_type] = pd.DataFrame({'col1': col1, 'col2': col2, 'difference': diff})

print('Is the selected palette accessible to all 4 vision types? ', accessible_all_types)
# Out:
# Is the selected palette accessible to all 4 vision types?  False

# %% [markdown]
# ### **View Test Results**    <a name="view_results_2"></a>

# %% [markdown]
# <h5 style="color: #999"> <b>Instructor Note:</b> The following code cell should be given to students. </h5>

# %%
"""
Expanded version of the output_cell_styling() function from Part 1.

Styles Pass/Fail cells to have green/red text.
Colors the text red in the difference column if the value is under the set tolerance level.
"""
def color_comparison_styling(column, tolerance=10):
    if column.name == 'difference':
        return ['color: red' if val < tolerance else 'color: default' for val in column]
    
    return ['text-align: center; color: ' + text_color_from_ratio(val) + '; background-color: ' + val if val[0] == '#' else \
            'text-align: center; font-weight: bold; color: green' if val == 'Pass' else \
            'text-align: center; font-weight: bold; color: red' for val in column]

# %%
"""
Add the pass_fail list to be the final row.
Style and display a summary of the accessibility tests.
"""
results_copy = my_results_df.copy()   
results_copy.loc[-1] = pass_fail
results_copy.style.apply(color_comparison_styling, tolerance=tolerance_threshold)
# Out:
# <style type="text/css">
# #T_72045_row0_col0 {
#   text-align: center;
#   color: black;
#   background-color: #6DC72C;
# }
# #T_72045_row0_col1 {
#   text-align: center;
#   color: black;
#   background-color: #D3AD2F;
# }
# #T_72045_row0_col2 {
#   text-align: center;
#   color: black;
#   background-color: #E1A451;
# }
# #T_72045_row0_col3 {
#   text-align: center;
#   color: black;
#   background-color: #8FAFBD;
# }
# #T_72045_row1_col0 {
#   text-align: center;
#   color: white;
#   background-color: #A35BA8;
# }
# #T_72045_row1_col1 {
#   text-align: center;
#   color: white;
#   background-color: #5D7DAD;
# }
# #T_72045_row1_col2 {
#   text-align: center;
#   color: white;
#   background-color: #6C7D96;
# }
# #T_72045_row1_col3 {
#   text-align: center;
#   color: white;
#   background-color: #946F76;
# }
# #T_72045_row2_col0 {
#   text-align: center;
#   color: white;
#   background-color: #D32248;
# }
# #T_72045_row2_col1 {
#   text-align: center;
#   color: white;
#   background-color: #4B5D5F;
# }
# #T_72045_row2_col2 {
#   text-align: center;
#   color: white;
#   background-color: #665B3C;
# }
# #T_72045_row2_col3 {
#   text-align: center;
#   color: white;
#   background-color: #C63437;
# }
# #T_72045_row3_col0 {
#   text-align: center;
#   color: white;
#   background-color: #DC367E;
# }
# #T_72045_row3_col1 {
#   text-align: center;
#   color: white;
#   background-color: #537091;
# }
# #T_72045_row3_col2 {
#   text-align: center;
#   color: white;
#   background-color: #6C6E6D;
# }
# #T_72045_row3_col3 {
#   text-align: center;
#   color: white;
#   background-color: #C94C51;
# }
# #T_72045_row4_col0, #T_72045_row4_col2 {
#   text-align: center;
#   font-weight: bold;
#   color: green;
# }
# #T_72045_row4_col1, #T_72045_row4_col3 {
#   text-align: center;
#   font-weight: bold;
#   color: red;
# }
# </style>
# <table id="T_72045">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72045_level0_col0" class="col_heading level0 col0" >True</th>
#       <th id="T_72045_level0_col1" class="col_heading level0 col1" >Protanopia</th>
#       <th id="T_72045_level0_col2" class="col_heading level0 col2" >Deuteranopia</th>
#       <th id="T_72045_level0_col3" class="col_heading level0 col3" >Tritanopia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72045_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72045_row0_col0" class="data row0 col0" >#6DC72C</td>
#       <td id="T_72045_row0_col1" class="data row0 col1" >#D3AD2F</td>
#       <td id="T_72045_row0_col2" class="data row0 col2" >#E1A451</td>
#       <td id="T_72045_row0_col3" class="data row0 col3" >#8FAFBD</td>
#     </tr>
#     <tr>
#       <th id="T_72045_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72045_row1_col0" class="data row1 col0" >#A35BA8</td>
#       <td id="T_72045_row1_col1" class="data row1 col1" >#5D7DAD</td>
#       <td id="T_72045_row1_col2" class="data row1 col2" >#6C7D96</td>
#       <td id="T_72045_row1_col3" class="data row1 col3" >#946F76</td>
#     </tr>
#     <tr>
#       <th id="T_72045_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72045_row2_col0" class="data row2 col0" >#D32248</td>
#       <td id="T_72045_row2_col1" class="data row2 col1" >#4B5D5F</td>
#       <td id="T_72045_row2_col2" class="data row2 col2" >#665B3C</td>
#       <td id="T_72045_row2_col3" class="data row2 col3" >#C63437</td>
#     </tr>
#     <tr>
#       <th id="T_72045_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72045_row3_col0" class="data row3 col0" >#DC367E</td>
#       <td id="T_72045_row3_col1" class="data row3 col1" >#537091</td>
#       <td id="T_72045_row3_col2" class="data row3 col2" >#6C6E6D</td>
#       <td id="T_72045_row3_col3" class="data row3 col3" >#C94C51</td>
#     </tr>
#     <tr>
#       <th id="T_72045_level0_row4" class="row_heading level0 row4" >-1</th>
#       <td id="T_72045_row4_col0" class="data row4 col0" >Pass</td>
#       <td id="T_72045_row4_col1" class="data row4 col1" >Fail</td>
#       <td id="T_72045_row4_col2" class="data row4 col2" >Pass</td>
#       <td id="T_72045_row4_col3" class="data row4 col3" >Fail</td>
#     </tr>
#   </tbody>
# </table>

# %%
"""
Style and display the saved test details as individual tables for each vision type.
"""
for vision_type, table in comparison_tables.items():
    styled_table = table.style.apply(color_comparison_styling) \
        .set_caption(vision_type) \
        .set_table_styles([
            {'selector': 'caption', 'props': 'font-size: large; font-weight: bold; margin-top: 20px;'}, 
            {'selector': 'td', 'props': 'border-bottom: 4px solid #404040'}
        ])
    
    display(styled_table)
# Out:
# <style type="text/css">
# #T_a5fcd caption {
#   font-size: large;
#   font-weight: bold;
#   margin-top: 20px;
# }
# #T_a5fcd td {
#   border-bottom: 4px solid #404040;
# }
# #T_a5fcd_row0_col0, #T_a5fcd_row1_col0, #T_a5fcd_row2_col0 {
#   text-align: center;
#   color: black;
#   background-color: #6DC72C;
# }
# #T_a5fcd_row0_col1, #T_a5fcd_row3_col0, #T_a5fcd_row4_col0 {
#   text-align: center;
#   color: white;
#   background-color: #A35BA8;
# }
# #T_a5fcd_row0_col2, #T_a5fcd_row1_col2, #T_a5fcd_row2_col2, #T_a5fcd_row3_col2, #T_a5fcd_row4_col2, #T_a5fcd_row5_col2 {
#   color: default;
# }
# #T_a5fcd_row1_col1, #T_a5fcd_row3_col1, #T_a5fcd_row5_col0 {
#   text-align: center;
#   color: white;
#   background-color: #D32248;
# }
# #T_a5fcd_row2_col1, #T_a5fcd_row4_col1, #T_a5fcd_row5_col1 {
#   text-align: center;
#   color: white;
#   background-color: #DC367E;
# }
# </style>
# <table id="T_a5fcd">
#   <caption>True</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5fcd_level0_col0" class="col_heading level0 col0" >col1</th>
#       <th id="T_a5fcd_level0_col1" class="col_heading level0 col1" >col2</th>
#       <th id="T_a5fcd_level0_col2" class="col_heading level0 col2" >difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5fcd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5fcd_row0_col0" class="data row0 col0" >#6DC72C</td>
#       <td id="T_a5fcd_row0_col1" class="data row0 col1" >#A35BA8</td>
#       <td id="T_a5fcd_row0_col2" class="data row0 col2" >79.624608</td>
#     </tr>
#     <tr>
#       <th id="T_a5fcd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5fcd_row1_col0" class="data row1 col0" >#6DC72C</td>
#       <td id="T_a5fcd_row1_col1" class="data row1 col1" >#D32248</td>
#       <td id="T_a5fcd_row1_col2" class="data row1 col2" >78.042567</td>
#     </tr>
#     <tr>
#       <th id="T_a5fcd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5fcd_row2_col0" class="data row2 col0" >#6DC72C</td>
#       <td id="T_a5fcd_row2_col1" class="data row2 col1" >#DC367E</td>
#       <td id="T_a5fcd_row2_col2" class="data row2 col2" >82.727373</td>
#     </tr>
#     <tr>
#       <th id="T_a5fcd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5fcd_row3_col0" class="data row3 col0" >#A35BA8</td>
#       <td id="T_a5fcd_row3_col1" class="data row3 col1" >#D32248</td>
#       <td id="T_a5fcd_row3_col2" class="data row3 col2" >25.292778</td>
#     </tr>
#     <tr>
#       <th id="T_a5fcd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5fcd_row4_col0" class="data row4 col0" >#A35BA8</td>
#       <td id="T_a5fcd_row4_col1" class="data row4 col1" >#DC367E</td>
#       <td id="T_a5fcd_row4_col2" class="data row4 col2" >15.931108</td>
#     </tr>
#     <tr>
#       <th id="T_a5fcd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5fcd_row5_col0" class="data row5 col0" >#D32248</td>
#       <td id="T_a5fcd_row5_col1" class="data row5 col1" >#DC367E</td>
#       <td id="T_a5fcd_row5_col2" class="data row5 col2" >12.740143</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bc327 caption {
#   font-size: large;
#   font-weight: bold;
#   margin-top: 20px;
# }
# #T_bc327 td {
#   border-bottom: 4px solid #404040;
# }
# #T_bc327_row0_col0, #T_bc327_row1_col0, #T_bc327_row2_col0 {
#   text-align: center;
#   color: black;
#   background-color: #D3AD2F;
# }
# #T_bc327_row0_col1, #T_bc327_row3_col0, #T_bc327_row4_col0 {
#   text-align: center;
#   color: white;
#   background-color: #5D7DAD;
# }
# #T_bc327_row0_col2, #T_bc327_row1_col2, #T_bc327_row2_col2, #T_bc327_row3_col2, #T_bc327_row5_col2 {
#   color: default;
# }
# #T_bc327_row1_col1, #T_bc327_row3_col1, #T_bc327_row5_col0 {
#   text-align: center;
#   color: white;
#   background-color: #4B5D5F;
# }
# #T_bc327_row2_col1, #T_bc327_row4_col1, #T_bc327_row5_col1 {
#   text-align: center;
#   color: white;
#   background-color: #537091;
# }
# #T_bc327_row4_col2 {
#   color: red;
# }
# </style>
# <table id="T_bc327">
#   <caption>Protanopia</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc327_level0_col0" class="col_heading level0 col0" >col1</th>
#       <th id="T_bc327_level0_col1" class="col_heading level0 col1" >col2</th>
#       <th id="T_bc327_level0_col2" class="col_heading level0 col2" >difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc327_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc327_row0_col0" class="data row0 col0" >#D3AD2F</td>
#       <td id="T_bc327_row0_col1" class="data row0 col1" >#5D7DAD</td>
#       <td id="T_bc327_row0_col2" class="data row0 col2" >49.877837</td>
#     </tr>
#     <tr>
#       <th id="T_bc327_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc327_row1_col0" class="data row1 col0" >#D3AD2F</td>
#       <td id="T_bc327_row1_col1" class="data row1 col1" >#4B5D5F</td>
#       <td id="T_bc327_row1_col2" class="data row1 col2" >44.547550</td>
#     </tr>
#     <tr>
#       <th id="T_bc327_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc327_row2_col0" class="data row2 col0" >#D3AD2F</td>
#       <td id="T_bc327_row2_col1" class="data row2 col1" >#537091</td>
#       <td id="T_bc327_row2_col2" class="data row2 col2" >52.818245</td>
#     </tr>
#     <tr>
#       <th id="T_bc327_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc327_row3_col0" class="data row3 col0" >#5D7DAD</td>
#       <td id="T_bc327_row3_col1" class="data row3 col1" >#4B5D5F</td>
#       <td id="T_bc327_row3_col2" class="data row3 col2" >21.263491</td>
#     </tr>
#     <tr>
#       <th id="T_bc327_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc327_row4_col0" class="data row4 col0" >#5D7DAD</td>
#       <td id="T_bc327_row4_col1" class="data row4 col1" >#537091</td>
#       <td id="T_bc327_row4_col2" class="data row4 col2" >6.302542</td>
#     </tr>
#     <tr>
#       <th id="T_bc327_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bc327_row5_col0" class="data row5 col0" >#4B5D5F</td>
#       <td id="T_bc327_row5_col1" class="data row5 col1" >#537091</td>
#       <td id="T_bc327_row5_col2" class="data row5 col2" >15.005199</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_951e9 caption {
#   font-size: large;
#   font-weight: bold;
#   margin-top: 20px;
# }
# #T_951e9 td {
#   border-bottom: 4px solid #404040;
# }
# #T_951e9_row0_col0, #T_951e9_row1_col0, #T_951e9_row2_col0 {
#   text-align: center;
#   color: black;
#   background-color: #E1A451;
# }
# #T_951e9_row0_col1, #T_951e9_row3_col0, #T_951e9_row4_col0 {
#   text-align: center;
#   color: white;
#   background-color: #6C7D96;
# }
# #T_951e9_row0_col2, #T_951e9_row1_col2, #T_951e9_row2_col2, #T_951e9_row3_col2, #T_951e9_row4_col2, #T_951e9_row5_col2 {
#   color: default;
# }
# #T_951e9_row1_col1, #T_951e9_row3_col1, #T_951e9_row5_col0 {
#   text-align: center;
#   color: white;
#   background-color: #665B3C;
# }
# #T_951e9_row2_col1, #T_951e9_row4_col1, #T_951e9_row5_col1 {
#   text-align: center;
#   color: white;
#   background-color: #6C6E6D;
# }
# </style>
# <table id="T_951e9">
#   <caption>Deuteranopia</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_951e9_level0_col0" class="col_heading level0 col0" >col1</th>
#       <th id="T_951e9_level0_col1" class="col_heading level0 col1" >col2</th>
#       <th id="T_951e9_level0_col2" class="col_heading level0 col2" >difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_951e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_951e9_row0_col0" class="data row0 col0" >#E1A451</td>
#       <td id="T_951e9_row0_col1" class="data row0 col1" >#6C7D96</td>
#       <td id="T_951e9_row0_col2" class="data row0 col2" >39.795078</td>
#     </tr>
#     <tr>
#       <th id="T_951e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_951e9_row1_col0" class="data row1 col0" >#E1A451</td>
#       <td id="T_951e9_row1_col1" class="data row1 col1" >#665B3C</td>
#       <td id="T_951e9_row1_col2" class="data row1 col2" >34.155868</td>
#     </tr>
#     <tr>
#       <th id="T_951e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_951e9_row2_col0" class="data row2 col0" >#E1A451</td>
#       <td id="T_951e9_row2_col1" class="data row2 col1" >#6C6E6D</td>
#       <td id="T_951e9_row2_col2" class="data row2 col2" >33.542821</td>
#     </tr>
#     <tr>
#       <th id="T_951e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_951e9_row3_col0" class="data row3 col0" >#6C7D96</td>
#       <td id="T_951e9_row3_col1" class="data row3 col1" >#665B3C</td>
#       <td id="T_951e9_row3_col2" class="data row3 col2" >30.414373</td>
#     </tr>
#     <tr>
#       <th id="T_951e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_951e9_row4_col0" class="data row4 col0" >#6C7D96</td>
#       <td id="T_951e9_row4_col1" class="data row4 col1" >#6C6E6D</td>
#       <td id="T_951e9_row4_col2" class="data row4 col2" >13.179862</td>
#     </tr>
#     <tr>
#       <th id="T_951e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_951e9_row5_col0" class="data row5 col0" >#665B3C</td>
#       <td id="T_951e9_row5_col1" class="data row5 col1" >#6C6E6D</td>
#       <td id="T_951e9_row5_col2" class="data row5 col2" >14.999817</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_73653 caption {
#   font-size: large;
#   font-weight: bold;
#   margin-top: 20px;
# }
# #T_73653 td {
#   border-bottom: 4px solid #404040;
# }
# #T_73653_row0_col0, #T_73653_row1_col0, #T_73653_row2_col0 {
#   text-align: center;
#   color: black;
#   background-color: #8FAFBD;
# }
# #T_73653_row0_col1, #T_73653_row3_col0, #T_73653_row4_col0 {
#   text-align: center;
#   color: white;
#   background-color: #946F76;
# }
# #T_73653_row0_col2, #T_73653_row1_col2, #T_73653_row2_col2, #T_73653_row3_col2, #T_73653_row4_col2 {
#   color: default;
# }
# #T_73653_row1_col1, #T_73653_row3_col1, #T_73653_row5_col0 {
#   text-align: center;
#   color: white;
#   background-color: #C63437;
# }
# #T_73653_row2_col1, #T_73653_row4_col1, #T_73653_row5_col1 {
#   text-align: center;
#   color: white;
#   background-color: #C94C51;
# }
# #T_73653_row5_col2 {
#   color: red;
# }
# </style>
# <table id="T_73653">
#   <caption>Tritanopia</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73653_level0_col0" class="col_heading level0 col0" >col1</th>
#       <th id="T_73653_level0_col1" class="col_heading level0 col1" >col2</th>
#       <th id="T_73653_level0_col2" class="col_heading level0 col2" >difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73653_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73653_row0_col0" class="data row0 col0" >#8FAFBD</td>
#       <td id="T_73653_row0_col1" class="data row0 col1" >#946F76</td>
#       <td id="T_73653_row0_col2" class="data row0 col2" >35.251176</td>
#     </tr>
#     <tr>
#       <th id="T_73653_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73653_row1_col0" class="data row1 col0" >#8FAFBD</td>
#       <td id="T_73653_row1_col1" class="data row1 col1" >#C63437</td>
#       <td id="T_73653_row1_col2" class="data row1 col2" >47.799451</td>
#     </tr>
#     <tr>
#       <th id="T_73653_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73653_row2_col0" class="data row2 col0" >#8FAFBD</td>
#       <td id="T_73653_row2_col1" class="data row2 col1" >#C94C51</td>
#       <td id="T_73653_row2_col2" class="data row2 col2" >43.984672</td>
#     </tr>
#     <tr>
#       <th id="T_73653_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73653_row3_col0" class="data row3 col0" >#946F76</td>
#       <td id="T_73653_row3_col1" class="data row3 col1" >#C63437</td>
#       <td id="T_73653_row3_col2" class="data row3 col2" >20.244424</td>
#     </tr>
#     <tr>
#       <th id="T_73653_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73653_row4_col0" class="data row4 col0" >#946F76</td>
#       <td id="T_73653_row4_col1" class="data row4 col1" >#C94C51</td>
#       <td id="T_73653_row4_col2" class="data row4 col2" >16.465529</td>
#     </tr>
#     <tr>
#       <th id="T_73653_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_73653_row5_col0" class="data row5 col0" >#C63437</td>
#       <td id="T_73653_row5_col1" class="data row5 col1" >#C94C51</td>
#       <td id="T_73653_row5_col2" class="data row5 col2" >6.042396</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Data Visualization Demo**     <a name="demo"></a>
#
# It's time to see these colors in action!
#
# Create some basic subplots to visualize how your selected color palette will appear to each of the vision types. Use this exercise to make the ultimate decision of whether or not the palette is accessible. If some palettes were able to pass the accessibility test but still look confusing when plotted, try adjusting the `tolerance_threshold`, switching out some colors, and running the test again.

# %%
from random import randint

"""
Generate semi-random points to plot for each color in the original palette.
These points will be reused to make identical subplots for each vision type
"""
x_data = range(8)
y_data = []
for i in range(len(my_results_df['True'])):
    y_data.append([randint(1+i,4+i) for j in x_data])   # using randint(1+i,4+i) helps keep the plots from looking too messy

count = 0
for vision_type, color_list in my_results_df.items():
    count += 1
    plt.subplot(2,2,count)
    plt.xlim(0, 7)
    plt.ylim(0, 2*len(color_list))
    plt.title(vision_type)
    plt.tight_layout()

    for i in range(len(color_list)):
        plt.plot(x_data, y_data[i], c=color_list[i])

plt.show()

# %% [markdown]
# ---
# ## **Part 3:** Simulating Images  <a name="sim_img"></a>
#
# ---

# %% [markdown]
# #### **Step 1:** Get and Reshape Image    <a name="img_step1"></a>
#
#
# To use an image from a URL, we need to import two additional library modules:
#
# -  `urllib.request` - This module is needed for opening the URL with the `urlopen()` function, which returns the data as a response. It's particularly useful for fetching data across the web, such as HTML pages, images, or other types of files.
# -  `io` - The `BytesIO()` function wraps the byte data of the image into a binary stream object that can be used as if it were a file. This is necessary because `plt.imread()` expects a file-like object to read from.
#
# Other functions used:
#
# - `plt.imread()` - Takes the image data and `format=` to produce a numpy array that can be used by other `plt` functions for displaying. Be sure that `format=` matches the file extension found in the URL! (typically ***jpg*** or ***png***) <br /> This function can also be used to directly read images that are stored locally using a file path (ex: `plt.imread('images/my_pic.png')`).
#
#
# **Note:** Be sure that the URL is for the image itself, not simply the site where the image is used!
#
# After getting and reading the image, the resulting numpy array should have three dimensions *(height in pixels, width in pixels, color channels)*. Typically, there will be either 3 or 4 color channels, depending on whether the color space of the image is RGB or RGBA. In order to move on the **Step 2**, the shape of the array must be reshaped to 2D. Save the original shape of the image so that the data predicted by the model can be arranged back into the correct width and height later.

# %%
import urllib.request
import io

url = 'https://publicdomainarchive.com/img/c-domain-images-free-stock-photos-high-quality-resolution-downloads-public-domain-archive-6-1000x664_sa5h7xe208pxvz0mk6ptr8.jpg'
with urllib.request.urlopen(url) as response:
   img = plt.imread(io.BytesIO(response.read()), format='jpg')

img_shape = img.shape
img_reshaped = img.reshape(-1,img_shape[2])
print(img_shape, '-->', img_reshaped.shape)
# Out:
# (664, 1000, 3) --> (664000, 3)

# %% [markdown]
# #### **Step 2:** Format as a DataFrame and Predict   <a name="img_step2"></a>
#
# First, convert the numpy array into a pandas dataframe that the trained model will recognize. This includes assigning the correct column names. If the color space of the image was RGBA (final dimension=4), then an additional column name is required and the extra column containing the alpha channel data will eventually need to be dropped. Optionally, this column can can be saved and appended back later (recommended for PNG images with transparency).
#
# The RGB data in images may either be represented on a scale of 0-255 (int) or 0-1 (float). Since the model has been trained on RGB data in the 0-255 format, the RGB values from the image must be multiplied by 255 if they are in float format.
#
# Lastly, use the trained model to predict what each RGB pixel would look like to those with the three vision deficiency types.

# %%
if img_shape[2] == 4:
    img_df = pd.DataFrame(img_reshaped, columns=['true_red','true_green','true_blue','a'])
    alpha = img_df['a']
    img_df = img_df.drop(columns=['a'])
else:
    img_df = pd.DataFrame(img_reshaped, columns=['true_red','true_green','true_blue'])
    alpha = len(img_df) * [1.0]

if isinstance(img[0][0][0], np.float32):
    img_df[img_df.select_dtypes(include=['number']).columns] *= 255.0
else:
    img_df[img_df.select_dtypes(include=['number']).columns] *= 1.0
    
img_pred = reg_model.predict(img_df)

# %% [markdown]
# #### **Step 3:** Format the Output    <a name="img_step3"></a>
#
# The resulting output array from the model prediction contains a row for each pixel where every row has 9 values; the 3 RGB values for each vision deficiency type. This data must be split up into 3 separate numpy arrays with the same dimensions as the original image. This process may take a few seconds to execute depending the resolution of the original image.
#
#
# <font color="#999"> **Instructor Note:** If you find a better, more efficient way of implementing this, please do so! </font>

# %%
count = 0
prot = []
deut = []
trit = []
for x in range(img_shape[0]):
    prot_row = []
    deut_row = []
    trit_row = []
    for y in range(img_shape[1]):
        row = img_pred[count]
        prot_row.append([row[0]/255.0, row[1]/255.0, row[2]/255.0, alpha[count]])
        deut_row.append([row[3]/255.0, row[4]/255.0, row[5]/255.0, alpha[count]])
        trit_row.append([row[6]/255.0, row[7]/255.0, row[8]/255.0, alpha[count]])
        count += 1
    prot.append(prot_row)
    deut.append(deut_row)
    trit.append(trit_row)

images = {'Original':img, 'Protanopia':np.array(prot), 'Deuteranopia':np.array(deut), 'Tritanopia':np.array(trit)}

# %% [markdown]
# #### **Step 4:** Display Simulated Images    <a name="img_step4"></a>
#
# Use `plt.imshow()` to display an image on a plot, title it by its vision type, and turn off the axis. All images can be viewed side-by-side using the subplot function.

# %%
plt.figure(figsize=(20,5))

count = 1
for key, val in images.items():
    plt.subplot(1,4,count)
    plt.imshow(val)
    plt.axis('off')
    plt.title(key, fontsize=25)
    count += 1

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
